# %%
import requests

# %% [markdown]
# https://news.daum.net/economic

# %%
path = 'https://news.daum.net/economic'
req = requests.get(path)

# %%
req.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(req.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="os_unknown none unknown version_0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer">
# <meta content="Daum 뉴스" property="og:author"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="경제" property="og:title"/>
# <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <meta content="https://news.daum.net/economic" property="og:url"/>
# <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>경제 | 다음뉴스</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//t1.daumcdn.net/media/kraken/news/e3d4c16/common.css.merged.css" rel="stylesheet" type="text/css">
# <link href="//t1.daumcdn.net/media/kraken/news/e3d4c16/news.css.merged.css" rel="stylesheet" type="text/css"/>
# ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.select('strong.tit_timenews > a[href].link_txt')
# Out:
# []
